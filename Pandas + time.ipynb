# %% [markdown]
# https://lerner.co.il
#
# https://WeeklyPythonExercise.com/

# %% [markdown]
# https://github.com/reuven/dfw-pandas

# %% [markdown]
# # Pandas times + dates
#
# - Reading in date/time data
# - Extracting date/time info
# - Date calculations
# - Date and time indexes
# - Time series

# %%
# !ls
# Out:
# 'Pandas + time.ipynb'   README.md~		    taxi.csv
#  README.md	        celebrity_deaths_2016.csv

# %%
# !head taxi.csv
# Out:
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
# 2,2015-06-02 11:19:29,2015-06-02 11:47:52,1,1.63,-73.954429626464844,40.764141082763672,1,N,-73.974754333496094,40.754093170166016,2,17,0,0.5,0,0,0.3,17.8
# 2,2015-06-02 11:19:30,2015-06-02 11:27:56,1,.46,-73.971443176269531,40.758941650390625,1,N,-73.978538513183594,40.761909484863281,1,6.5,0,0.5,1,0,0.3,8.3
# 2,2015-06-02 11:19:31,2015-06-02 11:30:30,1,.87,-73.978111267089844,40.738433837890625,1,N,-73.990272521972656,40.745437622070313,1,8,0,0.5,2.2,0,0.3,11
# 2,2015-06-02 11:19:31,2015-06-02 11:39:02,1,2.13,-73.945892333984375,40.773529052734375,1,N,-73.971527099609375,40.760330200195312,1,13.5,0,0.5,2.86,0,0.3,17.16
# ...

# %%
import pandas as pd
from pandas import Series, DataFrame

df = pd.read_csv('taxi.csv', usecols=['tpep_pickup_datetime',
                                     'tpep_dropoff_datetime',
                                     'passenger_count','trip_distance',
                                     'total_amount'])

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-06-02 11:19:29   2015-06-02 11:47:52                1           1.63
# 1  2015-06-02 11:19:30   2015-06-02 11:27:56                1           0.46
# 2  2015-06-02 11:19:31   2015-06-02 11:30:30                1           0.87
# 3  2015-06-02 11:19:31   2015-06-02 11:39:02                1           2.13
# 4  2015-06-02 11:19:32   2015-06-02 11:32:49                1           1.40
#
#    total_amount
# 0         17.80
# 1          8.30
# 2         11.00
# 3         17.16
# 4         10.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   9999 non-null   object
#  1   tpep_dropoff_datetime  9999 non-null   object
#  2   passenger_count        9999 non-null   int64
#  3   trip_distance          9999 non-null   float64
#  4   total_amount           9999 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 390.7+ KB

# %%
# datetime / timestamp -- marks a moment time
# interval / timedelta -- marks a stretch of time (relative)

# %%
import pandas as pd
from pandas import Series, DataFrame

df = pd.read_csv('taxi.csv', usecols=['tpep_pickup_datetime',
                                     'tpep_dropoff_datetime',
                                     'passenger_count','trip_distance',
                                     'total_amount'],
                parse_dates=['tpep_pickup_datetime',
                           'tpep_dropoff_datetime'])

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-06-02 11:19:29   2015-06-02 11:47:52                1           1.63
# 1  2015-06-02 11:19:30   2015-06-02 11:27:56                1           0.46
# 2  2015-06-02 11:19:31   2015-06-02 11:30:30                1           0.87
# 3  2015-06-02 11:19:31   2015-06-02 11:39:02                1           2.13
# 4  2015-06-02 11:19:32   2015-06-02 11:32:49                1           1.40
#
#    total_amount
# 0         17.80
# 1          8.30
# 2         11.00
# 3         17.16
# 4         10.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   9999 non-null   datetime64[ns]
#  1   tpep_dropoff_datetime  9999 non-null   datetime64[ns]
#  2   passenger_count        9999 non-null   int64
#  3   trip_distance          9999 non-null   float64
#  4   total_amount           9999 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(1)
# memory usage: 390.7 KB

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
# 1-2-2020  # Jan 2? Feb 1?

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-06-02 11:19:29   2015-06-02 11:47:52                1           1.63
# 1  2015-06-02 11:19:30   2015-06-02 11:27:56                1           0.46
# 2  2015-06-02 11:19:31   2015-06-02 11:30:30                1           0.87
# 3  2015-06-02 11:19:31   2015-06-02 11:39:02                1           2.13
# 4  2015-06-02 11:19:32   2015-06-02 11:32:49                1           1.40
#
#    total_amount
# 0         17.80
# 1          8.30
# 2         11.00
# 3         17.16
# 4         10.30

# %%
# you can use the "str" proxy object on a text column to run methods on strings
# datetime columns have the "dt" proxy object

# %%
df['tpep_pickup_datetime'].dt.hour.value_counts().plot.pie()

# %%
df['ride_time'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-06-02 11:19:29   2015-06-02 11:47:52                1           1.63
# 1  2015-06-02 11:19:30   2015-06-02 11:27:56                1           0.46
# 2  2015-06-02 11:19:31   2015-06-02 11:30:30                1           0.87
# 3  2015-06-02 11:19:31   2015-06-02 11:39:02                1           2.13
# 4  2015-06-02 11:19:32   2015-06-02 11:32:49                1           1.40
#
#    total_amount ride_time
# 0         17.80  00:28:23
# 1          8.30  00:08:26
# 2         11.00  00:10:59
# 3         17.16  00:19:31
# 4         10.30  00:13:17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   9999 non-null   datetime64[ns]
#  1   tpep_dropoff_datetime  9999 non-null   datetime64[ns]
#  2   passenger_count        9999 non-null   int64
#  3   trip_distance          9999 non-null   float64
#  4   total_amount           9999 non-null   float64
#  5   ride_time              9999 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), timedelta64[ns](1)
# memory usage: 468.8 KB

# %%
df[df['ride_time'] > '1:00:00']
# Out:
#      tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 7     2015-06-02 11:19:35   2015-06-02 12:36:46                4
#
# 2015-06-02 11:19:31                 1   2015-06-02 11:39:02           2.13
# 2015-06-02 11:19:32                 1   2015-06-02 11:32:49           1.40
# ...                               ...                   ...            ...
# 2015-06-02 11:33:35                 1   2015-06-02 11:42:16           0.73
# 2015-06-02 11:33:35                 1   2015-06-02 11:38:53           0.96
# 2015-06-02 11:33:36                 2   2015-06-02 11:52:32           3.50
# 2015-06-02 11:33:35                 5   2015-06-02 11:55:02           2.14
# 2015-06-02 11:33:30                 5   2015-06-02 11:42:45           0.61
#
#                       total_amount ride_time
# ...

# %%
df.resample('1H').mean()
# Out:
#                       passenger_count  trip_distance  total_amount
# tpep_pickup_datetime
# 2015-06-01 00:00:00          1.610906       4.312809     18.932686
# 2015-06-01 01:00:00               NaN            NaN           NaN
# 2015-06-01 02:00:00               NaN            NaN           NaN
# 2015-06-01 03:00:00               NaN            NaN           NaN
# 2015-06-01 04:00:00               NaN            NaN           NaN
# ...                               ...            ...           ...
# 2015-06-06 12:00:00               NaN            NaN           NaN
# 2015-06-06 13:00:00               NaN            NaN           NaN
# 2015-06-06 14:00:00               NaN            NaN           NaN
# 2015-06-06 15:00:00               NaN            NaN           NaN
# 2015-06-06 16:00:00          1.748408       2.852166     14.929936
#
# [137 rows x 3 columns]

# %%
df.resample('1H').mean().dropna()
# Out:
#                       passenger_count  trip_distance  total_amount
# tpep_pickup_datetime
# 2015-06-01 00:00:00          1.610906       4.312809     18.932686
# 2015-06-02 11:00:00          1.646497       2.661199     16.582095
# 2015-06-04 15:00:00          1.706625       2.986285     18.556569
# 2015-06-06 16:00:00          1.748408       2.852166     14.929936

# %%
df.resample('8H').mean().dropna()
# Out:
#                       passenger_count  trip_distance  total_amount
# tpep_pickup_datetime
# 2015-06-01 00:00:00          1.610906       4.312809     18.932686
# 2015-06-02 08:00:00          1.646497       2.661199     16.582095
# 2015-06-04 08:00:00          1.706625       2.986285     18.556569
# 2015-06-06 16:00:00          1.748408       2.852166     14.929936

# %%
# !ls
# Out:
# 'Pandas + time.ipynb'   README.md~		    taxi.csv
#  README.md	        celebrity_deaths_2016.csv

# %%
df = pd.read_csv('celebrity_deaths_2016.csv',
                usecols=['dateofdeath', 'age', 'causeofdeath'],
                parse_dates=['dateofdeath'])

# %%
df.head(20)
# Out:
#    dateofdeath age                causeofdeath
# 0   2016-01-01  71                brain cancer
# 1   2016-01-01  74                      cancer
# 2   2016-01-01  79                      cancer
# 3   2016-01-01  45   complications of a stroke
# 4   2016-01-01  83               heart failure
# 5   2016-01-01  71                 lung cancer
# 6   2016-01-01  92                         NaN
# 7   2016-01-01  99                         NaN
# 8   2016-01-01  45                         NaN
# 9   2016-01-01  58                         NaN
# 10  2016-01-01  75                         NaN
# 11  2016-01-01  80                         NaN
# 12  2016-01-01  82                         NaN
# 13  2016-01-01  85                         NaN
# 14  2016-01-01  89                         NaN
# 15  2016-01-01  89                         NaN
# 16  2016-01-01  89                         NaN
# 17  2016-01-01  90                         NaN
# 18  2016-01-01  93                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dateofdeath   6543 non-null   datetime64[ns]
#  1   age           6516 non-null   object
#  2   causeofdeath  1535 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 153.5+ KB

# %%
df['causeofdeath'] = df['causeofdeath'].fillna('Unknown')

# %%
df.head()
# Out:
#   dateofdeath age                causeofdeath
# 0  2016-01-01  71                brain cancer
# 1  2016-01-01  74                      cancer
# 2  2016-01-01  79                      cancer
# 3  2016-01-01  45   complications of a stroke
# 4  2016-01-01  83               heart failure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dateofdeath   6543 non-null   datetime64[ns]
#  1   age           6516 non-null   object
#  2   causeofdeath  6543 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 153.5+ KB

# %%
import numpy as np
df['age'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-b615f54c842c> in <module>
#       1 import numpy as np
# ----> 2 df['age'].astype(np.int64)
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.shape
# Out:
# (6543, 3)

# %%
df.describe()
# Out:
#                 dateofdeath   age causeofdeath
# count                  6543  6516         6543
# unique                  364   138          362
# top     2016-11-28 00:00:00    86      Unknown
# freq                     43   236         5008
# first   2016-01-01 00:00:00   NaN          NaN
# last    2016-12-29 00:00:00   NaN          NaN

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#                 dateofdeath   age causeofdeath
# count                  6516  6516         6516
# unique                  364   138          360
# top     2016-11-28 00:00:00    86      Unknown
# freq                     42   236         4985
# first   2016-01-01 00:00:00   NaN          NaN
# last    2016-12-29 00:00:00   NaN          NaN

# %%
df['age'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-4e15edd815b4> in <module>
# ----> 1 df['age'].astype(np.int64)
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df = df[df['age'].str.isdigit()]
df.head()
# Out:
#   dateofdeath age                causeofdeath
# 0  2016-01-01  71                brain cancer
# 1  2016-01-01  74                      cancer
# 2  2016-01-01  79                      cancer
# 3  2016-01-01  45   complications of a stroke
# 4  2016-01-01  83               heart failure

# %%
df['age'] = df['age'].astype(np.int64)

# %%
df.head()
# Out:
#   dateofdeath  age                causeofdeath
# 0  2016-01-01   71                brain cancer
# 1  2016-01-01   74                      cancer
# 2  2016-01-01   79                      cancer
# 3  2016-01-01   45   complications of a stroke
# 4  2016-01-01   83               heart failure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6481 entries, 0 to 6542
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dateofdeath   6481 non-null   datetime64[ns]
#  1   age           6481 non-null   int64
#  2   causeofdeath  6481 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 202.5+ KB

# %%
df = df.set_index('dateofdeath')
df.head()
# Out:
#              age                causeofdeath
# dateofdeath
# 2016-01-01    71                brain cancer
# 2016-01-01    74                      cancer
# 2016-01-01    79                      cancer
# 2016-01-01    45   complications of a stroke
# 2016-01-01    83               heart failure

# %%
df = df.drop('causeofdeath', axis='columns')

# %%
df.head()
# Out:
#              age
# dateofdeath
# 2016-01-01    71
# 2016-01-01    74
# 2016-01-01    79
# 2016-01-01    45
# 2016-01-01    83

# %%
df.resample('1M').mean()
# Out:
#                    age
# dateofdeath
# 2016-01-31   77.772932
# 2016-02-29   77.716364
# 2016-03-31   76.352381
# 2016-04-30   76.491525
# 2016-05-31   76.986717
# 2016-06-30   77.282197
# 2016-07-31   78.362454
# 2016-08-31   77.822266
# 2016-09-30   76.959514
# 2016-10-31   77.051485
# 2016-11-30   75.622266
# 2016-12-31   75.566265

# %%
df.resample('1M').mean().plot.line()

# %%
df.resample('1M').count()
# Out:
#              age
# dateofdeath
# 2016-01-31   665
# 2016-02-29   550
# 2016-03-31   630
# 2016-04-30   531
# 2016-05-31   527
# 2016-06-30   528
# 2016-07-31   538
# 2016-08-31   512
# 2016-09-30   494
# 2016-10-31   505
# 2016-11-30   503
# 2016-12-31   498

# %%
df.resample('1M').count().plot.line()

# %% [markdown]
# https://BetterDevelopersWeekly.com

# %%
mylist = [10, 20, 30]
my_other_list = [40, 50, 60]

pd.
